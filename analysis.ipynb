# %%
# Auto-install required packages
import subprocess
import sys

def install_if_missing(package_name, import_name=None):
    """Install package if it's not already installed"""
    if import_name is None:
        import_name = package_name
    
    try:
        __import__(import_name)
        print(f"✓ {package_name} is already installed")
    except ImportError:
        print(f"Installing {package_name}...")
        subprocess.check_call([sys.executable, "-m", "pip", "install", package_name])
        print(f"✓ {package_name} installed successfully")

# Install required packages
install_if_missing("yfinance")
install_if_missing("matplotlib")
# Out:
# ✓ yfinance is already installed
# ✓ matplotlib is already installed

# %%
import yfinance as yf

df = yf.download("AAPL", start = "2023-01-01", end = "2024-01-01")
print(df.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2023-01-03  122.982712  128.715409  122.097730  128.105761  112117500
# 2023-01-04  124.251183  126.512801  122.992546  124.772336   89113600
# 2023-01-05  122.933540  125.637646  122.677885  125.008327   80962700
# 2023-01-06  127.456779  128.115596  122.805722  123.907033   87754700
# 2023-01-09  127.977936  131.183540  127.722280  128.292603   70790800

# %%
import yfinance as yf
import matplotlib.pyplot as plt

# Get user input for ticker and date range
ticker = input("Enter ticker symbol (e.g., AAPL, TSLA, GOOGL): ").upper()
start_date = input("Enter start date (YYYY-MM-DD) [default: 2025-01-01]: ") or "2025-01-01"
end_date = input("Enter end date (YYYY-MM-DD) [default: 2026-01-01]: ") or "2026-01-01"

# Download data
df = yf.download(ticker, start=start_date, end=end_date)
print(f"\n{ticker} Stock Data ({start_date} to {end_date}):")
print(df.head())

# Plot the stock data
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['Close'], label='Close Price', linewidth=2)
plt.xlabel('Date')
plt.ylabel('Price ($)')
plt.title(f'{ticker} Stock Price ({start_date} to {end_date})')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# GOOGL Stock Data (2026-03-14 to 2026-04-14):
# Price            Close        High         Low        Open    Volume
# Ticker           GOOGL       GOOGL       GOOGL       GOOGL     GOOGL
# Date
# 2026-03-16  305.377594  306.307032  302.839102  304.168325  23519700
# 2026-03-17  310.734406  311.234107  305.317628  305.677398  21955200
# 2026-03-18  307.506317  312.283462  306.746761  309.085360  20009800
# 2026-03-19  306.946655  307.876093  302.169510  303.828523  25075800
# 2026-03-20  300.820312  305.817328  298.091931  305.277641  44364100
